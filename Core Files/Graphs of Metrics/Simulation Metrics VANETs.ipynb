# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
## ScoreTable metrics

## DELTA of 0.2
scoretable_accuracy_city_2 = np.array([0.783646, 0.731816, 0.746317, 0.678991]) * 100
scoretable_precision_city_2 = np.array([0.567266, 0.793917, 0.965491, 0.989753]) * 100
scoretable_recall_city_2 = np.array([0.603922, 0.539003, 0.543681, 0.531928]) * 100
scoretable_specificity_city_2 = np.array([0.863089, 0.894005, 0.981708, 0.992284]) * 100
scoretable_f1_score_city_2 = np.array([0.557079, 0.621525, 0.661603, 0.669085]) * 100
scoretable_avg_detection_time_city_2 = np.array([9.36788, 23.9052, 22.1344, 27.5414])

scoretable_accuracy_highway_2 = np.array([0.74895, 0.641598, 0.53231, 0.587661]) * 100
scoretable_precision_highway_2 = np.array([0.619705, 0.813955, 0.827143, 0.857127]) * 100
scoretable_recall_highway_2 = np.array([0.468217, 0.344452, 0.280247, 0.386624]) * 100
scoretable_specificity_highway_2 = np.array([0.888716, 0.935274, 0.923552, 0.916505]) * 100
scoretable_f1_score_highway_2 = np.array([0.480023, 0.430744, 0.395121, 0.502559]) * 100
scoretable_avg_detection_time_highway_2 = np.array([9.56485, 12.9158, 20.3476, 31.2091])

## DELTA of 0.3
scoretable_accuracy_city_3 = np.array([0.764083, 0.686121, 0.700141, 0.656326]) * 100
scoretable_precision_city_3 = np.array([0.626642, 0.560108, 0.759883, 0.798198]) * 100
scoretable_recall_city_3 = np.array([0.595752, 0.496223, 0.581108, 0.468692]) * 100
scoretable_specificity_city_3 = np.array([0.848995, 0.784714, 0.829233, 0.886875]) * 100
scoretable_f1_score_city_3 = np.array([0.547952, 0.552986, 0.626566, 0.611131]) * 100
scoretable_avg_detection_time_city_3 = np.array([8.36817, 14.5962, 20.0439, 26.7127])

scoretable_accuracy_highway_3 = np.array([0.810872, 0.647834, 0.672276, 0.596794]) * 100
scoretable_precision_highway_3 = np.array([0.840653, 0.78487, 0.89579, 0.863143]) * 100
scoretable_recall_highway_3 = np.array([0.573256, 0.428317, 0.461169, 0.45357]) * 100
scoretable_specificity_highway_3 = np.array([0.961939, 0.864112, 0.937404, 0.881725]) * 100
scoretable_f1_score_highway_3 = np.array([0.644576, 0.521887, 0.593691, 0.558301]) * 100
scoretable_avg_detection_time_highway_3 = np.array([8.44161, 17.0933, 16.891, 23.8968])

## DELTA of .4 - Best Results
scoretable_accuracy_city_4 = np.array([0.823549, 0.820114, 0.782885, 0.789126]) * 100
scoretable_precision_city_4 = np.array([0.5682, 0.610126, 0.785839, 0.844755]) * 100
scoretable_recall_city_4 = np.array([0.837255, 0.698836, 0.734112, 0.672917]) * 100
scoretable_specificity_city_4 = np.array([0.833055, 0.857972, 0.874397, 0.93699]) * 100
scoretable_f1_score_city_4 = np.array([0.633708, 0.639538, 0.714318, 0.679714]) * 100
scoretable_avg_detection_time_city_4 = np.array([12.3627, 25.0653, 35.0036, 39.2614])


scoretable_accuracy_highway_4 = np.array([0.878138, 0.74373, 0.622391, 0.696688]) * 100
scoretable_precision_highway_4 = np.array([0.86892, 0.958333, 1.0, 0.991111]) * 100
scoretable_recall_highway_4 = np.array([0.739535, 0.518724, 0.447471, 0.539477]) * 100
scoretable_specificity_highway_4 = np.array([0.959921, 0.986429, 1.0, 0.993333]) * 100
scoretable_f1_score_highway_4 = np.array([0.753538, 0.605148, 0.570259, 0.666776]) * 100
scoretable_avg_detection_time_highway_4 = np.array([5.66716, 13.8783, 19.0369, 23.2558])

## DELTA OF .5
scoretable_accuracy_city_5 = np.array([0.805834, 0.828798, 0.718028, 0.757627]) * 100
scoretable_precision_city_5 = np.array([0.667717, 0.918939, 0.818862, 0.845304]) * 100
scoretable_recall_city_5 = np.array([0.688235, 0.669025, 0.582837, 0.695523]) * 100
scoretable_specificity_city_5 = np.array([0.868647, 0.956063, 0.869064, 0.864232]) * 100
scoretable_f1_score_city_5 = np.array([0.640645, 0.747791, 0.639471, 0.75708]) * 100
scoretable_avg_detection_time_city_5 = np.array([8.38062, 14.528, 19.0419, 23.3391])

scoretable_accuracy_highway_5 = np.array([0.884117, 0.74373, 0.622391, 0.696688]) * 100
scoretable_precision_highway_5 = np.array([0.879167, 0.958333, 1, 0.991111]) * 100
scoretable_recall_highway_5 = np.array([0.726744, 0.518724, 0.447471, 0.539477]) * 100
scoretable_specificity_highway_5 = np.array([0.958976, 0.986429, 1, 0.993333]) * 100
scoretable_f1_score_highway_5 = np.array([0.791976, 0.605148, 0.570259, 0.666776]) * 100
scoretable_avg_detection_time_highway_5 = np.array([5.43993, 13.8783, 19.0369, 23.2558])

# %%
deltas = [0.2, 0.3, 0.4, 0.5]
markers = ['o', 's', '^', 'x']

# City data
city_data = {
    "Accuracy": [scoretable_accuracy_city_2, scoretable_accuracy_city_3, scoretable_accuracy_city_4, scoretable_accuracy_city_5],
    "Precision": [scoretable_precision_city_2, scoretable_precision_city_3, scoretable_precision_city_4, scoretable_precision_city_5],
    "Recall": [scoretable_recall_city_2, scoretable_recall_city_3, scoretable_recall_city_4, scoretable_recall_city_5],
    "Specificity": [scoretable_specificity_city_2, scoretable_specificity_city_3, scoretable_specificity_city_4, scoretable_specificity_city_5],
    "F1 Score": [scoretable_f1_score_city_2, scoretable_f1_score_city_3, scoretable_f1_score_city_4, scoretable_f1_score_city_5],
    "Avg Detection Time": [scoretable_avg_detection_time_city_2, scoretable_avg_detection_time_city_3, scoretable_avg_detection_time_city_4, scoretable_avg_detection_time_city_5]
}

# Highway data
highway_data = {
    "Accuracy": [scoretable_accuracy_highway_2, scoretable_accuracy_highway_3, scoretable_accuracy_highway_3, scoretable_accuracy_highway_5],
    "Precision": [scoretable_precision_highway_2, scoretable_precision_highway_3, scoretable_precision_highway_3, scoretable_precision_highway_5],
    "Recall": [scoretable_recall_highway_2, scoretable_recall_highway_3, scoretable_recall_highway_3, scoretable_recall_highway_5],
    "Specificity": [scoretable_specificity_highway_2, scoretable_specificity_highway_3, scoretable_specificity_highway_3, scoretable_specificity_highway_5],
    "F1 Score": [scoretable_f1_score_highway_2, scoretable_f1_score_highway_3, scoretable_f1_score_highway_3, scoretable_f1_score_highway_5],
    "Avg Detection Time": [scoretable_avg_detection_time_highway_2, scoretable_avg_detection_time_highway_3, scoretable_avg_detection_time_highway_3, scoretable_avg_detection_time_highway_5]
}

# Plotting
metrics = list(city_data.keys())  # Assuming city and highway have same metrics
num_plots = len(metrics)

plt.figure(figsize=(20, 20))
for i, metric in enumerate(metrics):
    plt.subplot(num_plots, 2, i*2+1)
    for j, delta in enumerate(deltas):
        plt.plot(range(10, 50, 10), highway_data[metric][j], label=f'Delta = {delta}', marker=markers[j], linestyle='-')
    plt.xlabel('Malicious Nodes (%)')
    if (metric == 'Avg Detection Time'):
        plt.ylabel('Detection Time (epochs)')
    else:
        plt.ylabel(f'{metric} (%)')
    plt.title(f'Highway {metric} Comparison')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(num_plots, 2, i*2+2)
    for j, delta in enumerate(deltas):
        plt.plot(range(10, 50, 10), city_data[metric][j], label=f'Delta = {delta}', marker=markers[j], linestyle='-')
    plt.xlabel('Malicious Nodes (%)')
    if (metric == 'Avg Detection Time'):
        plt.ylabel('Detection Time (epochs)')
    else:
        plt.ylabel(f'{metric} (%)')
    plt.title(f'Highway {metric} Comparison')
    plt.title(f'City {metric} Comparison')
    plt.legend()
    plt.grid(True)
    
    
    
plt.tight_layout()
plt.show()

# %%
## Hostbased Metrics
hostbased_accuracy_highway = np.array([0.868475, 0.786174, 0.668536, 0.583959]) * 100
hostbased_precision_highway = np.array([0.661043, 0.707547, 0.79659, 0.922438]) * 100
hostbased_specificity_highway = np.array([0.959831, 0.947424, 0.920561, 0.956476]) * 100
hostbased_avg_detection_time_highway = np.array([18.7736, 13.0176, 17.1131, 42.7633])

hostbased_accuracy_city = np.array([0.836933, 0.744737, 0.657097, 0.517165]) * 100
hostbased_precision_city = np.array([0.726623, 0.851185, 0.70886, 0.867582]) * 100
hostbased_recall_city = np.array([0.58268, 0.376877, 0.2826, 0.200205]) * 100
hostbased_specificity_city = np.array([0.896981, 0.981227, 0.954708, 0.960363]) * 100
hostbased_f1_score_city = np.array([0.556681, 0.482632, 0.353738, 0.31137]) * 100
hostbased_avg_detection_time_city = np.array([44.2804, 42.5696, 49.8932, 76.6496])

# %%
## Trustgroup Metrics
trustgroup_accuracy_highway = np.array([0.702641, 0.653413, 0.678795, 0.760632]) * 100
trustgroup_precision_highway = np.array([0.631534, 0.723212, 0.825039, 0.894005]) * 100
trustgroup_specificity_highway = np.array([0.828342, 0.772489, 0.753742, 0.911461]) * 100
trustgroup_avg_detection_time_highway = np.array([29.0625, 40.4834, 52.3063, 59.2398])

trustgroup_accuracy_city = np.array([0.588711, 0.702963, 0.709405, 0.69175]) * 100
trustgroup_precision_city = np.array([0.226722, 0.638459, 0.64332, 0.658135]) * 100
trustgroup_specificity_city = np.array([0.637512, 0.64174, 0.673727, 0.593907]) * 100
trustgroup_avg_detection_time_city = np.array([18.0842, 36.2328, 40.2527, 46.5326])

# %%
## Scoretable new metrics

scoretable_accuracy_highway = np.array([0.937926, 0.833315, 0.767764, 0.752577]) * 100
scoretable_precision_highway = np.array([0.93451, 0.928551, 0.944412, 0.91623]) * 100
scoretable_recall_highway = np.array([0.895349, 0.758833, 0.666237, 0.645901]) * 100
scoretable_specificity_highway = np.array([0.963619, 0.935976, 0.928, 0.961444]) * 100
scoretable_f1_score_highway = np.array([0.893249, 0.780422, 0.705276, 0.692097]) * 100
scoretable_avg_detection_time_highway = np.array([7.64916, 12.9704, 12.1149, 16.1273])

scoretable_accuracy_city = np.array([0.944263, 0.924519, 0.920112, 0.865461]) * 100
scoretable_precision_city = np.array([0.878867, 0.865337, 0.839194, 0.840788]) * 100
scoretable_recall_city = np.array([0.774837, 0.942125, 0.950206, 0.880288]) * 100
scoretable_specificity_city = np.array([0.970486, 0.924562, 0.897274, 0.888611]) * 100
scoretable_f1_score_city = np.array([0.784669, 0.882753, 0.89694, 0.831142]) * 100
scoretable_avg_detection_time_city = np.array([9.79732, 8.88481, 12.0375, 11.6506])

# %%
## Trust Group new metrics
trustgroup_accuracy_city = np.array([0.720068, 0.688769, 0.801872, 0.758989]) * 100
trustgroup_precision_city = np.array([0.36592, 0.433421, 0.519893, 0.501491]) * 100
trustgroup_recall_city = np.array([0.504139, 0.753808, 0.639964, 0.662347]) * 100
trustgroup_specificity_city = np.array([0.756739, 0.663223, 0.794549, 0.661192]) * 100
trustgroup_f1_score_city = np.array([0.355478, 0.48109, 0.502005, 0.497842]) * 100
trustgroup_avg_detection_time_city = np.array([74.5095, 93.2623, 116.997, 142.923])

trustgroup_accuracy_highway = np.array([0.731237, 0.620267, 0.713595, 0.819038]) * 100
trustgroup_precision_highway = np.array([0.674412, 0.607115, 0.839586, 0.897991]) * 100
trustgroup_recall_highway = np.array([0.613248, 0.446526, 0.616902, 0.720505]) * 100
trustgroup_specificity_highway = np.array([0.826095, 0.737538, 0.807723, 0.966363]) * 100
trustgroup_f1_score_highway = np.array([0.563554, 0.447061, 0.669849, 0.773858]) * 100
trustgroup_avg_detection_time_highway = np.array([26.8238, 38.0005, 54.6524, 63.8666])

# %%
## Host-based new metrics
"""
hostbased_accuracy_city = np.array([0.76351, 0.725947, 0.649929, 0.567992]) * 100
hostbased_precision_city = np.array([0.512885, 0.576088, 0.590826, 0.682546]) * 100
hostbased_recall_city = np.array([0.772222, 0.761966, 0.651801, 0.485387]) * 100
hostbased_specificity_city = np.array([0.732615, 0.706419, 0.648678, 0.69292]) * 100
hostbased_f1_score_city = np.array([0.615476, 0.643686, 0.594972, 0.546809]) * 100
hostbased_avg_detection_time_city = np.array([34.3412, 33.0664, 38.5891, 97.8973])

hostbased_accuracy_highway = np.array([0.800774, 0.809279, 0.75582, 0.752798]) * 100
hostbased_precision_highway = np.array([0.646636, 0.754489, 0.792482, 0.814874]) * 100
hostbased_recall_highway = np.array([0.828968, 0.785468, 0.684857, 0.642711]) * 100
hostbased_specificity_highway = np.array([0.750099, 0.770208, 0.754762, 0.823846]) * 100
hostbased_f1_score_highway = np.array([0.729054, 0.759595, 0.712636, 0.694138]) * 100
hostbased_avg_detection_time_highway = np.array([13.6735, 11.6732, 11.9589, 12.0304])
"""
# Out:
# '\nhostbased_accuracy_city = np.array([0.76351, 0.725947, 0.649929, 0.567992]) * 100\nhostbased_precision_city = np.array([0.512885, 0.576088, 0.590826, 0.682546]) * 100\nhostbased_recall_city = np.array([0.772222, 0.761966, 0.651801, 0.485387]) * 100\nhostbased_specificity_city = np.array([0.732615, 0.706419, 0.648678, 0.69292]) * 100\nhostbased_f1_score_city = np.array([0.615476, 0.643686, 0.594972, 0.546809]) * 100\nhostbased_avg_detection_time_city = np.array([34.3412, 33.0664, 38.5891, 97.8973])\n\nhostbased_accuracy_highway = np.array([0.800774, 0.809279, 0.75582, 0.752798]) * 100\nhostbased_precision_highway = np.array([0.646636, 0.754489, 0.792482, 0.814874]) * 100\nhostbased_recall_highway = np.array([0.828968, 0.785468, 0.684857, 0.642711]) * 100\nhostbased_specificity_highway = np.array([0.750099, 0.770208, 0.754762, 0.823846]) * 100\nhostbased_f1_score_highway = np.array([0.729054, 0.759595, 0.712636, 0.694138]) * 100\nhostbased_avg_detection_time_highway = np.array([13.6
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the percentages array
percentages = np.array([10, 20, 30, 40])

# Define y-ticks arrays
y_ticks_time_highway = np.arange(0, max(trustgroup_avg_detection_time_highway) + 20, 15)
y_ticks_time_city = np.arange(0, max(trustgroup_avg_detection_time_city) + 20, 15)
y_ticks_metrics = np.arange(0, 101, 10)

# Create subplots for each set of data
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4, 2, figsize=(16, 16))

# Plot for Highway Accuracy
ax1.plot(percentages, scoretable_accuracy_highway, label='ScoreTable', marker='x')
ax1.plot(percentages, hostbased_accuracy_highway, label='Host-Based IDS', marker='o')
ax1.plot(percentages, trustgroup_accuracy_highway, label='Trust Model - Secure Group*', marker='+')

ax1.set_title('Highway Accuracy')
ax1.set_ylabel('Accuracy (%)')
ax1.set_xlabel('Malicious Nodes in Network (%)')
ax1.set_xticks(np.arange(10, 41, 5))  # Adjust x ticks to start at 10 and intervals of 5
ax1.legend()

# Plot for City Accuracy
ax2.plot(percentages, scoretable_accuracy_city, label='ScoreTable', marker='x')
ax2.plot(percentages, hostbased_accuracy_city, label='Host-Based IDS', marker='o')
ax2.plot(percentages, trustgroup_accuracy_city, label='Trust Model - Secure Group*', marker='+')

ax2.set_title('City Accuracy')
ax2.set_ylabel('Accuracy (%)')
ax2.set_xlabel('Malicious Nodes in Network (%)')
ax2.set_xticks(np.arange(10, 41, 5))  # Adjust x ticks to start at 10 and intervals of 5
ax2.legend()

# Plot for Highway Precision
ax3.plot(percentages, scoretable_precision_highway, label='ScoreTable', marker='x')
ax3.plot(percentages, hostbased_precision_highway, label='Host-Based IDS', marker='o')
ax3.plot(percentages, trustgroup_precision_highway, label='Trust Model - Secure Group*', marker='+')

ax3.set_title('Highway Precision')
ax3.set_ylabel('Precision (%)')
ax3.set_xlabel('Malicious Nodes in Network (%)')
ax3.set_xticks(np.arange(10, 41, 5))  # Adjust x ticks to start at 10 and intervals of 5
ax3.legend()

# Plot for City Precision
ax4.plot(percentages, scoretable_precision_city, label='ScoreTable', marker='x')
ax4.plot(percentages, hostbased_precision_city, label='Host-Based IDS', marker='o')
ax4.plot(percentages, trustgroup_precision_highway, label='Trust Model - Secure Group*', marker='+')

ax4.set_title('City Precision')
ax4.set_xlabel('Malicious Nodes in Network (%)')
ax4.set_ylabel('Precision (%)')
ax4.set_xticks(np.arange(10, 41, 5))  # Adjust x ticks to start at 10 and intervals of 5
ax4.legend()

# Plot for Highway Specificity
ax5.plot(percentages, scoretable_specificity_highway, label='ScoreTable', marker='x')
ax5.plot(percentages, hostbased_specificity_highway, label='Host-Based IDS', marker='o')
ax5.plot(percentages, trustgroup_specificity_highway, label='Trust Model - Secure Group*', marker='+')

ax5.set_title('Highway Specificity')
ax5.set_xlabel('Malicious Nodes in Network (%)')
ax5.set_ylabel('Specificity (%)')
ax5.set_xticks(np.arange(10, 41, 5))  # Adjust x ticks to start at 10 and intervals of 5
ax5.legend()

# Plot for City Specificity
ax6.plot(percentages, scoretable_specificity_city, label='ScoreTable', marker='x')
ax6.plot(percentages, hostbased_specificity_city, label='Host-Based IDS', marker='o')
ax6.plot(percentages, trustgroup_specificity_city, label='Trust Model - Secure Group*', marker='+')

ax6.set_title('City Specificity')
ax6.set_xlabel('Malicious Nodes in Network (%)')
ax6.set_ylabel('Specificity (%)')
ax6.set_xticks(np.arange(10, 41, 5))  # Adjust x ticks to start at 10 and intervals of 5
ax6.legend()

# Plot for Highway Average Detection Time
ax7.plot(percentages, scoretable_avg_detection_time_highway, label='ScoreTable', marker='x')
ax7.plot(percentages, hostbased_avg_detection_time_highway, label='Host-Based IDS', marker='o')
ax7.plot(percentages, trustgroup_avg_detection_time_highway, label='Trust Model - Secure Group*', marker='+')

ax7.set_title('Highway Avg Detection Time')
ax7.set_xlabel('Malicious Nodes in Network (%)')
ax7.set_ylabel('Avg Detection Time')
ax7.set_xticks(np.arange(10, 41, 5))  # Adjust x ticks to start at 10 and intervals of 5
ax7.set_yticks(y_ticks_time_highway)  # Adjust y ticks for highway
ax7.legend()

# Plot for City Average Detection Time
ax8.plot(percentages, scoretable_avg_detection_time_city, label='ScoreTable', marker='x')
ax8.plot(percentages, hostbased_avg_detection_time_city, label='Host-Based IDS', marker='o')
ax8.plot(percentages, trustgroup_avg_detection_time_city, label='Trust Model - Secure Group*', marker='+')

ax8.set_title('City Avg Detection Time')
ax8.set_xlabel('Malicious Nodes in Network (%)')
ax8.set_ylabel('Avg Detection Time')
ax8.set_xticks(np.arange(10, 41, 5))  # Adjust x ticks to start at 10 and intervals of 5
ax8.set_yticks(y_ticks_time_city)  # Adjust y ticks for city
ax8.legend()

# Grid for all subplots
for ax in fig.get_axes():
    ax.grid(True)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
## Comparison with Delta = 0.5
# Define the percentages array
"""
percentages = np.array([10, 20, 30, 40])

# Define y-ticks arrays
y_ticks_time = np.arange(0, max(max(hostbased_avg_detection_time_highway), max(scoretable_avg_detection_time_highway_5),
                                 max(hostbased_avg_detection_time_city), max(scoretable_avg_detection_time_city_5)) + 10, 10)
y_ticks_metrics = np.arange(0, 101, 10)

# Create subplots for each set of data
#fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4, 2, figsize=(16, 16))
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4, 2, figsize=(16, 16))

# Plot for Highway Accuracy
ax1.plot(percentages, scoretable_accuracy_highway_5, label='ScoreTable', marker='x')
ax1.plot(percentages, hostbased_accuracy_highway, label='Host-Based IDS', marker='o')
ax1.plot(percentages, trustgroup_accuracy_highway, label='Trust Model - Secure Group*', marker='+')

ax1.set_title('Highway Accuracy')
ax1.set_ylabel('Accuracy (%)')
ax1.set_xlabel('Malicious Nodes in Network (%)')
ax1.set_xticks(percentages)
ax1.legend()

# Plot for City
ax2.plot(percentages, scoretable_accuracy_city_5, label='ScoreTable', marker='x')
ax2.plot(percentages, hostbased_accuracy_city, label='Host-Based IDS', marker='o')
ax2.plot(percentages, trustgroup_accuracy_city, label='Trust Model - Secure Group*', marker='+')

ax2.set_title('City Accuracy')
ax2.set_ylabel('Accuracy (%)')
ax2.set_xlabel('Malicious Nodes in Network (%)')
ax2.set_xticks(percentages)
ax2.legend()

# Plot for Highway Precision
ax3.plot(percentages, scoretable_precision_highway_5, label='ScoreTable', marker='x')
ax3.plot(percentages, hostbased_precision_highway, label='Host-Based IDS', marker='o')
ax3.plot(percentages, trustgroup_precision_highway, label='Trust Model - Secure Group*', marker='+')

ax3.set_title('Highway Precision')
ax3.set_ylabel('Precision (%)')
ax3.set_xlabel('Malicious Nodes in Network (%)')
ax3.set_xticks(percentages)
ax3.legend()

# Plot for City Precision
ax4.plot(percentages, scoretable_precision_city_5, label='ScoreTable', marker='x')
ax4.plot(percentages, hostbased_precision_city, label='Host-Based IDS', marker='o')
ax4.plot(percentages, trustgroup_precision_highway, label='Trust Model - Secure Group*', marker='+')

ax4.set_title('City Precision')
ax4.set_xlabel('Malicious Nodes in Network (%)')
ax4.set_ylabel('Precision (%)')
ax4.set_xticks(percentages)
ax4.legend()

# Plot for Highway Specificity
ax5.plot(percentages, scoretable_specificity_highway_5, label='ScoreTable', marker='x')
ax5.plot(percentages, hostbased_specificity_highway, label='Host-Based IDS', marker='o')
ax5.plot(percentages, trustgroup_specificity_highway, label='Trust Model - Secure Group*', marker='+')

ax5.set_title('(e) Highway Specificity')
ax5.set_xlabel('Malicious Nodes in Network (%)')
ax5.set_ylabel('Specificity (%)')
ax5.set_xticks(percentages)
ax5.legend()

# Plot for City Specificity
ax6.plot(percentages, scoretable_specificity_city_5, label='ScoreTable', marker='x')
ax6.plot(percentages, hostbased_specificity_city, label='Host-Based IDS', marker='o')
ax6.plot(percentages, trustgroup_specificity_city, label='Trust Model - Secure Group*', marker='+')

ax6.set_title('(f) City Specificity')
ax6.set_xlabel('Malicious Nodes in Network (%)')
ax6.set_ylabel('Specificity (%)')
ax6.set_xticks(percentages)
ax6.legend()

# Plot for Highway Average Detection Time
ax7.plot(percentages, scoretable_avg_detection_time_highway_5, label='ScoreTable', marker='x')
ax7.plot(percentages, hostbased_avg_detection_time_highway, label='Host-Based IDS', marker='o')
ax7.plot(percentages, trustgroup_avg_detection_time_highway, label='Trust Model - Secure Group*', marker='+')

ax7.set_title('Highway Avg Detection Time')
ax7.set_xlabel('Malicious Nodes in Network (%)')
ax7.set_ylabel('Avg Detection Time')
ax7.set_xticks(percentages)
ax7.set_yticks(y_ticks_time)
ax7.legend()

# Plot for City Average Detection Time
ax8.plot(percentages, scoretable_avg_detection_time_city_5, label='ScoreTable', marker='x')
ax8.plot(percentages, hostbased_avg_detection_time_city, label='Host-Based IDS', marker='o')
ax8.plot(percentages, trustgroup_avg_detection_time_city, label='Trust Model - Secure Group*', marker='+')

ax8.set_title('City Avg Detection Time')
ax8.set_xlabel('Malicious Nodes in Network (%)')
ax8.set_ylabel('Avg Detection Time')
ax8.set_xticks(percentages)
ax8.set_yticks(y_ticks_time)
ax8.legend()


ax1.grid(True)
ax2.grid(True)
ax3.grid(True)
ax4.grid(True)
ax5.grid(True)
ax6.grid(True)
ax7.grid(True)
ax8.grid(True)

# Adjust layout
plt.tight_layout()
#plt.subplots_adjust(wspace=1, hspace=1)
plt.show()
"""
# Out:
# "\npercentages = np.array([10, 20, 30, 40])\n\n# Define y-ticks arrays\ny_ticks_time = np.arange(0, max(max(hostbased_avg_detection_time_highway), max(scoretable_avg_detection_time_highway_5),\n                                 max(hostbased_avg_detection_time_city), max(scoretable_avg_detection_time_city_5)) + 10, 10)\ny_ticks_metrics = np.arange(0, 101, 10)\n\n# Create subplots for each set of data\n#fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4, 2, figsize=(16, 16))\nfig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4, 2, figsize=(16, 16))\n\n# Plot for Highway Accuracy\nax1.plot(percentages, scoretable_accuracy_highway_5, label='ScoreTable', marker='x')\nax1.plot(percentages, hostbased_accuracy_highway, label='Host-Based IDS', marker='o')\nax1.plot(percentages, trustgroup_accuracy_highway, label='Trust Model - Secure Group*', marker='+')\n\nax1.set_title('Highway Accuracy')\nax1.set_ylabel('Accuracy (%)')\nax1.set_xlabel('Malicious Nodes
# ...

# %%
## Scoretable metrics 5%-30%
scoretable_accuracy = np.array([0.961013, 0.944263, 0.936283, 0.924519, 0.939746, 0.920112]) * 100
scoretable_precision = np.array([0.870588, 0.878867, 0.90989, 0.865337, 0.869655, 0.839194]) * 100
scoretable_recall = np.array([0.941176, 0.774837, 0.926694, 0.942125, 0.965033, 0.950206]) * 100
scoretable_specificity = np.array([0.963843, 0.970486, 0.946833, 0.924562, 0.931623, 0.897274]) * 100
scoretable_f1_score = np.array([0.895881, 0.784669, 0.903248, 0.882753, 0.901665, 0.89694]) * 100
scoretable_avg_detection_time = np.array([7.16196, 9.79732, 10.2309, 8.88481, 9.35264, 12.0375])

## Hostbased metrics 5%-30%
hostbased_accuracy = np.array([0.886262, 0.76351, 0.823946, 0.725947, 0.711416, 0.649929]) * 100
hostbased_precision = np.array([0.192626, 0.512885, 0.502738, 0.576088, 0.510366, 0.590826]) * 100
hostbased_recall = np.array([0.393627, 0.772222, 0.273375, 0.761966, 0.235191, 0.651801]) * 100
hostbased_specificity = np.array([0.899581, 0.732615, 0.988309, 0.706419, 0.937595, 0.648678]) * 100
hostbased_f1_score = np.array([0.226956, 0.615476, 0.32924, 0.643686, 0.24869, 0.594972]) * 100
hostbased_avg_detection_time = np.array([19.8598, 34.3412, 19.9743, 33.0664, 22.3844, 38.5891])

## Trust group metrics 5%-30%
trustgroup_accuracy = np.array([0.288636, 0.720068, 0.688769, 0.309299, 0.492007, 0.801872]) * 100
trustgroup_precision = np.array([0.132405, 0.36592, 0.433421, 0.272746, 0.457225, 0.519893]) * 100
trustgroup_recall = np.array([0.930882, 0.504139, 0.753808, 0.881695, 0.91033, 0.639964]) * 100
trustgroup_specificity = np.array([0.216688, 0.756739, 0.663223, 0.150948, 0.221236, 0.794549]) * 100
trustgroup_f1_score = np.array([0.2071, 0.355478, 0.48109, 0.359028, 0.539376, 0.502005]) * 100
trustgroup_avg_detection_time = np.array([31.7774, 74.5095, 93.2623, 57.8249, 106.405, 116.997])

# %%
sybil_nodes = [5, 10, 15, 20, 25, 30]

# Create subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 10))

# Plot accuracy
axs[0, 0].plot(sybil_nodes, scoretable_accuracy, marker='x', label='Score Table')
axs[0, 0].plot(sybil_nodes, hostbased_accuracy, marker='o', label='Host-Based IDS')
axs[0, 0].plot(sybil_nodes, trustgroup_accuracy, marker='+', label='Trust Model - Secure Group*')
axs[0, 0].set_ylabel('Accuracy (%)')
axs[0, 0].set_ylim([0, 100])
axs[0, 0].set_yticks(range(0, 101, 10))
axs[0, 0].legend()
axs[0, 0].set_title('Accuracy')

# Plot precision
axs[0, 1].plot(sybil_nodes, scoretable_precision, marker='x', label='Score Table')
axs[0, 1].plot(sybil_nodes, hostbased_precision, marker='o', label='Host-Based IDS')
axs[0, 1].plot(sybil_nodes, trustgroup_precision, marker='+', label='Trust Model - Secure Group*')
axs[0, 1].set_ylabel('Precision (%)')
axs[0, 1].set_ylim([0, 100])
axs[0, 1].set_yticks(range(0, 101, 10))
axs[0, 1].legend()
axs[0, 1].set_title('Precision')

# Plot recall
axs[1, 0].plot(sybil_nodes, scoretable_recall, marker='x', label='Score Table')
axs[1, 0].plot(sybil_nodes, hostbased_recall, marker='o', label='Host-Based IDS')
axs[1, 0].plot(sybil_nodes, trustgroup_recall, marker='+', label='Trust Model - Secure Group*')
axs[1, 0].set_ylabel('Recall (%)')
axs[1, 0].set_ylim([0, 100])
axs[1, 0].set_yticks(range(0, 101, 10))
axs[1, 0].legend()
axs[1, 0].set_title('Recall')

# Plot specificity
axs[1, 1].plot(sybil_nodes, scoretable_specificity, marker='x', label='Score Table')
axs[1, 1].plot(sybil_nodes, hostbased_specificity, marker='o', label='Host-Based IDS')
axs[1, 1].plot(sybil_nodes, trustgroup_specificity, marker='+', label='Trust Model - Secure Group*')
axs[1, 1].set_ylabel('Specificity (%)')
axs[1, 1].set_ylim([0, 100])
axs[1, 1].set_yticks(range(0, 101, 10))
axs[1, 1].legend()
axs[1, 1].set_title('Specificity')

# Plot F1 score
axs[2, 0].plot(sybil_nodes, scoretable_f1_score, marker='x', label='Score Table')
axs[2, 0].plot(sybil_nodes, hostbased_f1_score, marker='o', label='Host-Based IDS')
axs[2, 0].plot(sybil_nodes, trustgroup_f1_score, marker='+', label='Trust Model - Secure Group*')
axs[2, 0].set_ylabel('F1 Score (%)')
axs[2, 0].set_ylim([0, 100])
axs[2, 0].set_yticks(range(0, 101, 10))
axs[2, 0].legend()
axs[2, 0].set_title('F1 Score')

# Plot average detection time
axs[2, 1].plot(sybil_nodes, scoretable_avg_detection_time, marker='x', label='Score Table')
axs[2, 1].plot(sybil_nodes, hostbased_avg_detection_time, marker='o', label='Host-Based IDS')
axs[2, 1].plot(sybil_nodes, trustgroup_avg_detection_time, marker='+', label='Trust Model - Secure Group*')
axs[2, 1].set_ylabel('Detection Time (Epochs)')
axs[2, 1].legend()
axs[2, 1].set_title('Average Detection Time')

# Set common x-axis label
for ax in axs.flat:
    ax.set_xlabel('Sybil Nodes in Network (%)')
    ax.set_xticks(sybil_nodes)
    ax.legend(fontsize='small')

for i in range(3):
    for j in range(2):
        axs[i, j].grid(True)    
    
# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
sybil_nodes = [5, 10, 15, 20, 25, 30]

scoretable_detection_times_delta03 = np.array([9.51495, 10.5915, 10.9979, 7.76879, 10.7788, 20.2917])
scoretable_detection_times_delta04 = np.array([7.16196, 9.79732, 10.2309, 8.88481, 9.35264, 12.0375])
scoretable_detection_times_delta05 = np.array([9.48531, 14.9398, 12.8492, 7.59432, 10.0076, 13.1075])


plt.plot(sybil_nodes, scoretable_detection_times_delta03, marker='x', label='Delta 0.3')
plt.plot(sybil_nodes, scoretable_detection_times_delta04, marker='o', label='Delta 0.4')
plt.plot(sybil_nodes, scoretable_detection_times_delta05, marker='D', label='Delta 0.5')
plt.xlabel('Sybil Nodes in Network (%)')
plt.ylabel('Detection Time (Epochs)')
plt.grid(True)
plt.legend()
plt.title('Average Detection Time - Delta Variance')
plt.show()
